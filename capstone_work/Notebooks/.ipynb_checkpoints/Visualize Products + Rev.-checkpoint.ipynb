# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pickle
import pprint
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/jonathanhilgart/anaconda/envs/SVB/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# # The following section uses no evidence in inference for the initial starting products

# %% [markdown]
# # Plot Confidence intervals for product LTVs

# %%
clients_over_time_per_week_no_evidence = pd.read_pickle("data-104-weeks/time_series_all_clients")
cumulative_clients_over_time_no_evidence = pd.read_pickle("data-104-weeks/times_series_cumulative_clients")
#cash management
cumulative_cm_customers_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_cash_management")
rev_customer_cm_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_cash_management_rev_per_customer")
total_weekly_rev_cm_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_cash_management_total_weekly_rev")
# checking
cumulative_checking_customers_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_checking")
rev_customer_checking_no_evidence  = pd.read_pickle("data-104-weeks/time_series_esp_checking_rev_per_customer")
total_weekly_rev_checking_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_checking_total_weekly_rev")
#CMMA
cumulative_cmma_customers_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_collateral_mma ")
rev_customer_cmma_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_collateral_mma_rev_per_customer")
total_weekly_rev_cmma_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_collateral_mma_total_weekly_rev")
# Enterprise Sweep
cumulative_es_customers_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_enterprise_sweep")
rev_customer_es_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_enterprise_sweep_rev_per_customer")
total_weekly_rev_es_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_enterprise_sweep_total_weekly_rev")
# FX
cumulative_fx_customers_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_fx")
rev_customer_fx_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_fx_rev_per_customer")
total_weekly_rev_fx_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_fx_total_weekly_rev")
# letters of credit
cumulative_loc_customers_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_letters_of_credit ")
rev_customer_loc_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_letters_of_credit_rev_per_customer")
total_weekly_rev_loc_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_letters_of_credit_total_weekly_rev")
#Money Market Bonus
cumulative_mmb_customers_no_evidence = pd.read_pickle("data-104-weeks/time_series_money_market_bonus")
rev_customer_mmb_no_evidence = pd.read_pickle("data-104-weeks/time_series_esp_money_market_bonus_rev_per_customer")
total_weekly_rev_mmb_no_evidence =  pd.read_pickle("data-104-weeks/time_series_esp_money_market_bonus_total_weekly_rev")

# %% [markdown]
# # Plot the percent of clients per product over time
# - Need to fix the denominator to not be checking

# %%
plt.figure(figsize=(12,8))
plt.plot([cumulative_cm_customers[0][i][2]/cumulative_checking_customers[0][i][2]
          for i in range(len(cumulative_clients))], label='percent of customers with cash management', color='black')
plt.plot([cumulative_checking_customers[0][i][2]/cumulative_checking_customers[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with checking')
plt.plot([cumulative_cmma_customers [0][i][2]/cumulative_checking_customers[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with collateral mma')
plt.plot([cumulative_es_customers [0][i][2]/cumulative_checking_customers[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with enterprise sweep')
plt.plot([cumulative_fx_customers [0][i][2]/cumulative_checking_customers[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with foreign exchange')
plt.plot([cumulative_loc_customers[0][i][2]/cumulative_checking_customers[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with letters of credit')
plt.plot([cumulative_mmb_customers [0][i][2]/cumulative_checking_customers[0][i][2]
          for i in range(len(cumulative_clients))], label = 'percent of customers with money market bonus')
plt.legend()
plt.xlabel('Weeks of simulated time')
plt.ylabel('Percent')
plt.title('Percent of all customers with a given product')

# %% [markdown]
# # Plot Revenue per product per client (time adjusted) over time

# %%
plt.figure(figsize=(12,8))
plt.plot([rev_customer_cm[0][i][2]
          for i in range(len(cumulative_clients))], label='Cash Mangement GP per customer', color ='orange')

plt.plot([rev_customer_checking[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Checking GP per customer')

plt.plot([rev_customer_cmma[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Collateral MMA GP per customer')
plt.plot([rev_customer_es[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Enterprise Sweep Gp per customer', color = 'red')
plt.plot([rev_customer_fx [0][i][2]
          for i in range(len(cumulative_clients))], label = 'Foreign Exchange GP per customer', color = 'black')
plt.plot([rev_customer_loc[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Letters of Credit GP per customer')
plt.plot([rev_customer_mmb[0][i][2]
          for i in range(len(cumulative_clients))], label = 'Money Market Bonus GP per customer', color = 'pink')
plt.legend()
plt.title('Time adjusted GP per product per customer')
plt.xlabel('Weeks of simulated time')
plt.ylabel('GP')
